# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %%
game = pd.read_csv('../data/clean_game_data.csv')
game
#DATAFRAME CLEANSING (STANDARDIZED NAMES) NEEDED
# Out:
#      Unnamed: 0  season  week         home_team         away_team  \
# 0             0    2013     1         Minnesota              UNLV
# 1             1    2013     1           Indiana     Indiana State
# 2             2    2013     1    Michigan State  Western Michigan
# 3             3    2013     1        Cincinnati            Purdue
# 4             4    2013     1         Wisconsin             UMass
# ..          ...     ...   ...               ...               ...
# 838         840    2021     4          Maryland        Kent State
# 839         841    2021     4          Michigan           Rutgers
# 840         842    2021     4    Michigan State          Nebraska
# 841         843    2021     4        Ohio State             Akron
# 842         844    2021     4  Western Kentucky           Indiana
#
#      home.totalYards  away.totalYards  Home_possession_time  \
# 0                320              419                  1286
# 1                632              306                  1286
# 2                297              204                  1286
# 3                425              226                  1286
# 4                598              212                  1286
# ..               ...              ...                   ...
# 838              528              458                  1286
# 839              275              352                  1286
# 840              254              444                  1286
# 841              622              229                  1286
# 842              458              507                  1286
#
#      Away_possession_time  Home_Offensive_TDs  Away_Offensive_TDs  \
# 0                    2314                   4                 3.0
# 1                    2314                   9                 3.0
# 2                    2314                   1                 2.0
# 3                    2314                   5                 1.0
# 4                    2314                   6                 0.0
# ..                    ...                 ...                 ...
# 838                  2314                   5                 1.0
# 839                  2314                   2                 1.0
# 840                  2314                   1                 2.0
# 841                  2314                   7                 1.0
# 842                  2314                   4                 3.0
#
#      home.turnovers  away.turnovers  home.thirdDownEff  home.fourthDownEff  \
# 0                 1               2           0.571429                1.00
# 1                 3               2           0.500000                0.50
# 2                 1               4           0.263158                0.00
# 3                 3               4           0.600000                0.75
# 4                 1               2           0.727273                0.00
# ..              ...             ...                ...                 ...
# 838               2               1           0.363636                0.50
# 839               0               1           0.363636                0.00
# 840               1               2           0.100000                0.00
# 841               1               2           0.727273                0.00
# 842               0               0           0.400000                0.50
#
#      away.thirdDownEff  away.fourthDownEff  away_points  home_points
# 0             0.333333            0.333333         23.0         51.0
# 1             0.187500            0.187500         35.0         73.0
# 2             0.200000            0.200000         13.0         26.0
# 3             0.333333            0.333333          7.0         42.0
# 4             0.428571            0.428571          0.0         45.0
# ..                 ...                 ...          ...          ...
# 838           0.250000            0.250000         16.0         37.0
# 839           0.437500            0.437500         13.0         20.0
# 840           0.368421            0.368421         20.0         23.0
# 841           0.277778            0.277778          7.0         59.0
# 842           0.611111            0.611111         33.0         31.0
#
# [843 rows x 19 columns]

# %%
game["point_diff"] = game["home_points"] - game["away_points"]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
X = game[["home.totalYards","Home_possession_time","Home_Offensive_TDs","home.turnovers"]].dropna()
y = game.loc[X.index]['point_diff']

# %%
X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=.3, random_state=0)
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
print(model.intercept_)
print(model.coef_)
print(model.score(X_test, y_test))
print(np.mean(model.predict(X_test)-y_test))
print(np.mean((model.predict(X_test)-y_test)**2)**0.5)
# Out:
# -21.779522666179904
# [ 1.82918679e-02  2.66453526e-15  7.30370284e+00 -3.42938633e+00]
# 0.6438234762153965
# -1.909200855701161
# 14.037698557066662
